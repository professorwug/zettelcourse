# %% [markdown]
# # Practice: Lecture Title
#
# Work through these exercises to reinforce your understanding of the material.
#
# **Instructions:**
# - Complete each section in order
# - Check your answers against the solutions at the end
# - Note any concepts you need to review

# %%
#|default_exp practice

# Standard imports
import numpy as np
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ---
#
# ## Part 1: Conceptual Questions
#
# Answer the following questions in your own words.

# %% [markdown]
# ### Question 1.1
#
# *Question text here...*
#
# **Your Answer:**
#
# *Write your answer here...*

# %% [markdown]
# ### Question 1.2 (Multiple Choice)
#
# *Question text here...*
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# **Your Answer:** _

# %% [markdown]
# ---
#
# ## Part 2: Coding Exercises
#
# Complete the following coding exercises.

# %% [markdown]
# ### Exercise 2.1
#
# *Instructions for the exercise...*
#
# **Requirements:**
# - Requirement 1
# - Requirement 2

# %%
# Your solution here
def exercise_2_1():
    """Implement the function."""
    pass

# Test your solution
# exercise_2_1()

# %% [markdown]
# ### Exercise 2.2
#
# *Instructions for the exercise...*

# %%
# Your solution here
pass

# %% [markdown]
# ---
#
# ## Part 3: Problem Sets
#
# These problems require combining multiple concepts.

# %% [markdown]
# ### Problem 3.1
#
# *Problem description...*

# %%
# Your solution here
pass

# %% [markdown]
# ---
#
# ## Solutions
#
# <details>
# <summary>Click to reveal solutions</summary>
#
# ### Solution 1.1
#
# *Detailed solution explanation...*
#
# ### Solution 1.2
#
# **Answer: B**
#
# *Explanation of why B is correct...*
#
# ### Solution 2.1
#
# ```python
# def exercise_2_1():
#     # Solution code here
#     pass
# ```
#
# *Explanation of the solution...*
#
# </details>

# %% [markdown]
# ---
#
# ## Self-Assessment
#
# Rate your understanding (1-5):
#
# | Topic | Rating | Notes |
# |-------|--------|-------|
# | Concept 1 | _ | |
# | Concept 2 | _ | |
# | Concept 3 | _ | |
#
# **Areas to review:**
# -
